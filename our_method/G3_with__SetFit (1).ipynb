# %%
# %pip install setfit

# %%
from huggingface_hub import notebook_login

notebook_login()
# Out:
# VBox(children=(HTML(value='<center> <img\nsrc=https://huggingface.co/front/assets/huggingface_logo-noborder.sv…

# %%
# !apt install git-lfs
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# git-lfs is already the newest version (3.0.2-1ubuntu0.2).
# 0 upgraded, 0 newly installed, 0 to remove and 24 not upgraded.

# %%
# !git config --global user.email "ja_mahmahi@esi.dz"
# !git config --global user.name "Anis Mahmahi"

# %%
model_id = "sentence-transformers/paraphrase-mpnet-base-v2"

# %%
import pandas as pd

train = pd.read_csv("/content/train-multi-label-oana.csv")
test = pd.read_csv("/content/test-multi-label-oana.csv")

# %%
train['Loaded_Language'].value_counts()
# Out:
# 0.0    2363
# 1.0    1784
# Name: Loaded_Language, dtype: int64

# %%
hq = pd.read_csv("/content/df_tweets_HiQualProp.csv")
hq
# Out:
#                         id                                               text  \
# 0      1372969669389393932  I only see a country corrupted and economicall...
# 1      1521594471279996928  New to you that Pope is on the side of murder ...
# 2      1385896329071632386  BJP PROPAGANDA AGAINST DELHI GOVT EXPOSED  Tot...
# 3      1403386698835365888  Senate Democrats threaten to subpoena Barr, Se...
# 4      1509240723362795531  Analysis: Russia understands Trump's utility e...
# ...                    ...                                                ...
# 29591  1564600447897243648  If your response to losing an election is to t...
# 29592  1569421814798876673  @brakerbaker @chrissyclark_ Biden is the one f...
# 29593  1570758041938841602  The historic victory of Ukraine in the Kharkiv...
# 29594  1573712319078871045  You can’t speak out about the injustice done t...
# 29595   821463133373992964  Greetings, I am still soliciting contributions...
#
#        labels                   strategy            author_id  labels_weak3  \
# 0           0          general discourse  1231542469252255745             0
# 1           0          general discourse  1231542469252255745             0
# 2           0          general discourse           2991581923             1
# 3           0          general discourse              2467791             1
# 4           0          general discourse              2467791             1
# ...       ...                        ...                  ...           ...
# 29591       0          general discourse  1187465769778442240             1
# 29592       1  against Western countries  1348870080856252417             1
# 29593       0          general discourse           2152685546             0
# 29594       0          general discourse  1556105145716740096             1
# 29595       0          general discourse            142419792             1
#
#        labels_weak2  labels_weak1     propaganda_category  \
# 0                 0             0                    none
# 1                 0             0                    none
# 2                 0             0                    none
# 3                 0             0                    none
# 4                 0             0                    none
# ...             ...           ...                     ...
# 29591             0             0                    none
# 29592             1             1  name_calling_labelling
# 29593             0             0                    none
# 29594             0             0                    none
# 29595             1             1                    none
#
#                                          text_normalized
# 0      I only see a country corrupted and economicall...
# 1      New to you that Pope is on the side of murder ...
# 2      BJP PROPAGANDA AGAINST DELHI GOVT EXPOSED Tota...
# 3      Senate Democrats threaten to subpoena Barr , S...
# 4      Analysis : Russia understands Trump 's utility...
# ...                                                  ...
# 29591  If your response to losing an election is to t...
# 29592  @USER @USER Biden is the one funding fascists ...
# 29593  The historic victory of Ukraine in the Kharkiv...
# 29594  You can't speak out about the injustice done t...
# 29595  Greetings , I am still soliciting contribution...
#
# [29596 rows x 10 columns]

# %%
hq['propaganda_category'].value_counts()
# Out:
# none                           25559
# slogans                         1584
# name_calling_labelling          1071
# loaded_language                  734
# appeal_to_fear_prejudice         492
# doubt                             64
# reductio_ad_hitelerium            50
# bandwagon                         25
# flag_waving                       13
# black_and_white_fallacy            1
# appeal_to_authority                1
# thought_terminating_cliches        1
# whataboutism                       1
# Name: propaganda_category, dtype: int64

# %%
hq_cleaned = hq[hq['propaganda_category']=='loaded_language'][['text_normalized', 'propaganda_category']]
hq_cleaned
# Out:
#                                          text_normalized propaganda_category
# 127    Almost everything they 're telling us is ' Rus...     loaded_language
# 140    Ukraine and NATO are running a propaganda war ...     loaded_language
# 147    Considering the fact that the Russians have ha...     loaded_language
# 169    Those who fell for the vaccine and mask propag...     loaded_language
# 232    What is n't reported in Western & Ukraine prop...     loaded_language
# ...                                                  ...                 ...
# 29499  ( 3/4 ) Other narratives have spread via @USER...     loaded_language
# 29527  @USER @USER @USER The propaganda is that every...     loaded_language
# 29534  @USER @USER @USER It appears you have no idea ...     loaded_language
# 29564  @USER Anyone who has time looking for infos on...     loaded_language
# 29578  @USER @USER @USER Do n't Fall for Anti-Russian...     loaded_language
#
# [734 rows x 2 columns]

# %%
hq_cleaned.rename(columns={'text_normalized':'text', 'propaganda_category':'label'}, inplace=True)

# %%
hq_cleaned['label']=1

# %%
hq_cleaned
# Out:
#                                                     text  label
# 127    Almost everything they 're telling us is ' Rus...      1
# 140    Ukraine and NATO are running a propaganda war ...      1
# 147    Considering the fact that the Russians have ha...      1
# 169    Those who fell for the vaccine and mask propag...      1
# 232    What is n't reported in Western & Ukraine prop...      1
# ...                                                  ...    ...
# 29499  ( 3/4 ) Other narratives have spread via @USER...      1
# 29527  @USER @USER @USER The propaganda is that every...      1
# 29534  @USER @USER @USER It appears you have no idea ...      1
# 29564  @USER Anyone who has time looking for infos on...      1
# 29578  @USER @USER @USER Do n't Fall for Anti-Russian...      1
#
# [734 rows x 2 columns]

# %%
train_cleaned = train[['text','Loaded_Language']].rename(columns={'Loaded_Language':"label"})
train_cleaned
# Out:
#                                                    text  label
# 0     Pamela Geller and Robert Spencer co-founded an...    0.0
# 1     He added: "We condemn all those whose behaviou...    0.0
# 2     Ms Geller, of the Atlas Shrugs blog, and Mr Sp...    0.0
# 3     On both of their blogs the pair called their b...    1.0
# 4     The UK should never become a stage for inflamm...    0.0
# ...                                                 ...    ...
# 4142  Comrades, these jokes you have been listening ...    0.0
# 4143  In the future everyone will be the subject of ...    1.0
# 4144                     Also the Left killed comedy.\n    0.0
# 4145  That's what Columbia snowflakes thought was of...    0.0
# 4146        I'm sure Patel felt very, like, accepted.\n    0.0
#
# [4147 rows x 2 columns]

# %%
test_cleaned = test[['text','Loaded_Language']].rename(columns={'Loaded_Language':"label"})
test_cleaned
# Out:
#                                                   text  label
# 0    "The next transmission could be more pronounce...      0
# 1    This along with poor sanitation and vector con...      0
# 2    Geneva - The World Health Organisation chief o...      0
# 3    But Tedros voiced alarm that "plague in Madaga...      0
# 4    He also pointed to the presence of the pneumon...      0
# ..                                                 ...    ...
# 982  The U.S. Department of Justice said the court ...      1
# 983  The Acosta-CNN lawsuit was filed by Ted Boutro...      0
# 984  The yanking of the physical credential, by the...      1
# 985  The president described Acosta as "unbelievabl...      0
# 986  "Journalists need to know that in this country...      0
#
# [987 rows x 2 columns]

# %%
result_df = pd.concat([train_cleaned, hq_cleaned], ignore_index=True)
result_df
# Out:
#                                                    text  label
# 0     Pamela Geller and Robert Spencer co-founded an...    0.0
# 1     He added: "We condemn all those whose behaviou...    0.0
# 2     Ms Geller, of the Atlas Shrugs blog, and Mr Sp...    0.0
# 3     On both of their blogs the pair called their b...    1.0
# 4     The UK should never become a stage for inflamm...    0.0
# ...                                                 ...    ...
# 4876  ( 3/4 ) Other narratives have spread via @USER...    1.0
# 4877  @USER @USER @USER The propaganda is that every...    1.0
# 4878  @USER @USER @USER It appears you have no idea ...    1.0
# 4879  @USER Anyone who has time looking for infos on...    1.0
# 4880  @USER @USER @USER Do n't Fall for Anti-Russian...    1.0
#
# [4881 rows x 2 columns]

# %%
result_df = result_df.dropna(subset=['text'])

# %%
result_df = result_df.sample(frac=1).reset_index(drop=True)

# %%
result_df.to_csv("train_cleaned.csv",index=False)

# %%
test_cleaned.to_csv("test_cleaned.csv",index=False)

# %%
from datasets import load_dataset


dataset = load_dataset('csv', data_files={'train': "/content/train_cleaned.csv",'test': "/content/test_cleaned.csv"}, )
dataset
# Out:
# Generating train split: 0 examples [00:00, ? examples/s]
# Generating test split: 0 examples [00:00, ? examples/s]
# DatasetDict({
#     train: Dataset({
#         features: ['text', 'label'],
#         num_rows: 4880
#     })
#     test: Dataset({
#         features: ['text', 'label'],
#         num_rows: 987
#     })
# })

# %%
from setfit import SetFitModel
from sentence_transformers import SentenceTransformer
from sklearn.linear_model import LogisticRegression

model_body=SentenceTransformer("sentence-transformers/paraphrase-mpnet-base-v2")
model_head=LogisticRegression(class_weight="balanced")
model = SetFitModel(model_body=model_body, model_head=model_head,labels=[0,1],)


# # Load a SetFit model from Hub
# model = SetFitModel.from_pretrained(
#     "sentence-transformers/paraphrase-mpnet-base-v2",
#     labels=[0,1],
# )

# %%
model.to("cuda")
# Out:
# SetFitModel(model_body=SentenceTransformer(
#   (0): Transformer({'max_seq_length': 512, 'do_lower_case': False}) with Transformer model: MPNetModel
#   (1): Pooling({'word_embedding_dimension': 768, 'pooling_mode_cls_token': False, 'pooling_mode_mean_tokens': True, 'pooling_mode_max_tokens': False, 'pooling_mode_mean_sqrt_len_tokens': False})
# ), model_head=LogisticRegression(class_weight='balanced'), multi_target_strategy=None, normalize_embeddings=False, labels=[0, 1], model_card_data=SetFitModelCardData(language=None, license=None, tags=['setfit', 'sentence-transformers', 'text-classification', 'generated_from_setfit_trainer'], model_name='SetFit', model_id=None, dataset_name=None, dataset_id=None, dataset_revision=None, task_name=None, st_id=None, hyperparameters={}, eval_results_dict={}, eval_lines_list=[], metric_lines=[], widget=[], predict_example=None, label_example_list=[], tokenizer_warning=False, train_set_metrics_list=[], train_set_sentences_per_label_list=[], code_carbon_callback=None, num_classes=None, best_model_step=None, metrics=['accuracy'], pipeline_tag='text-classification', library_name='setfit', version={'python': '3.10.12', 'setfit': '1.0.1', 'sentence_transformers': '2.2.2', 'transformers': '4.35.2', 'torch': '2.1.0+cu121', 'datasets': '2.16.1', 'tokenizers': '0.15.0'}))

# %%
from setfit import SetFitModel, Trainer, TrainingArguments, sample_dataset

args = TrainingArguments(
    batch_size=16,
    num_epochs=2,
    evaluation_strategy="epoch",
    save_strategy="epoch",
    load_best_model_at_end=True,
    num_iterations=5,
)

trainer = Trainer(
    model=model,
    args=args,
    train_dataset=dataset['train'],
    eval_dataset=dataset['test'],
    metric="f1",
    column_mapping={"text": "text", "label": "label"}  # Map dataset columns to text/label expected by trainer
)
# Out:
# Applying column mapping to the training dataset
# Applying column mapping to the evaluation dataset

# %%
import torch
training_device = torch.device("cuda") if torch.cuda.is_available() else torch.device("cpu")
training_device
# Out:
# device(type='cuda')

# %%
# Train and evaluate
trainer.train()
# Out:
# ***** Running training *****
#   Num examples = 3050
#   Num epochs = 2
#   Total optimization steps = 6100
#   Total train batch size = 16
#     <div>
#
#       <progress value='6100' max='6100' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [6100/6100 49:03, Epoch 2/0]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Embedding Loss</th>
#       <th>Rate</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>No log</td>
#       <td>No log</td>
#       <td>0.318700</td>
#       <td>0.000011</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>No log</td>
#       <td>No log</td>
#       <td>0.331300</td>
#       <td>0.000000</td>
#     </tr>
#   </tbody>
# </table><p>
#   0%|          | 0/617 [00:00<?, ?it/s]
#   0%|          | 0/617 [00:00<?, ?it/s]
# Loading best SentenceTransformer model from step 3050.

# %%
metrics = trainer.evaluate(dataset['test'])
print(metrics)
# Out:
# Applying column mapping to the evaluation dataset
# ***** Running evaluation *****
# Downloading builder script:   0%|          | 0.00/6.77k [00:00<?, ?B/s]
# {'f1': 0.6720214190093708}

# %%
trainer.push_to_hub("anismahmahi/G3-setfit-model")
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:72: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# Upload 2 LFS files:   0%|          | 0/2 [00:00<?, ?it/s]
# model.safetensors:   0%|          | 0.00/438M [00:00<?, ?B/s]
# model_head.pkl:   0%|          | 0.00/6.97k [00:00<?, ?B/s]
# CommitInfo(commit_url='https://huggingface.co/anismahmahi/G3-setfit-model/commit/2ebb0ccfb7b4daf8f231593626bdca8431926710', commit_message='Add SetFit model', commit_description='', oid='2ebb0ccfb7b4daf8f231593626bdca8431926710', pr_url=None, pr_revision=None, pr_num=None)

# %%
from sklearn.metrics import f1_score,classification_report
preds = model.predict(list(test['text']))

# %%
print(classification_report(dataset['test']['label'],preds))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.80      0.80      0.80       616
#          1.0       0.67      0.68      0.67       371
#
#     accuracy                           0.75       987
#    macro avg       0.74      0.74      0.74       987
# weighted avg       0.75      0.75      0.75       987
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
