# %%
# %pip install setfit
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.8/75.8 kB 467.8 kB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 507.1/507.1 kB 8.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.0/86.0 kB 4.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.1/84.1 kB 5.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 115.3/115.3 kB 6.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 9.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 29.2 MB/s eta 0:00:00
# ...
#   Created wheel for sentence-transformers: filename=sentence_transformers-2.2.2-py3-none-any.whl size=125923 sha256=7fd4e3adbfe29cfb7a02999bb11b2f2799331c758743e3ac36bba21a7ca89b9f
#   Stored in directory: /root/.cache/pip/wheels/62/f2/10/1e606fd5f02395388f74e7462910fe851042f97238cbbd902f
# Successfully built sentence-transformers
# ...

# %%
from huggingface_hub import notebook_login

notebook_login()

# %%
# !apt install git-lfs
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# git-lfs is already the newest version (3.0.2-1ubuntu0.2).
# 0 upgraded, 0 newly installed, 0 to remove and 24 not upgraded.

# %%
# !git config --global user.email "ja_mahmahi@esi.dz"
# !git config --global user.name "Anis Mahmahi"

# %%
model_id = "sentence-transformers/paraphrase-mpnet-base-v2"

# %%
import pandas as pd

train = pd.read_csv("/content/train-multi-label-oana.csv")

# %%
train['Loaded_Language'].value_counts()
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# 0.0    2363
# 1.0    1784
# Name: Loaded_Language, dtype: int64

# %%
train_cleaned = train[['text','Loaded_Language']]
train_cleaned
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#                                                    text  Loaded_Language
# 0     Pamela Geller and Robert Spencer co-founded an...              0.0
# 1     He added: "We condemn all those whose behaviou...              0.0
# 2     Ms Geller, of the Atlas Shrugs blog, and Mr Sp...              0.0
# 3     On both of their blogs the pair called their b...              1.0
# 4     The UK should never become a stage for inflamm...              0.0
# ...                                                 ...              ...
# 4142  Comrades, these jokes you have been listening ...              0.0
# ...

# %%
train_cleaned = train_cleaned.dropna()
train_cleaned
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#                                                    text  Loaded_Language
# 0     Pamela Geller and Robert Spencer co-founded an...              0.0
# 1     He added: "We condemn all those whose behaviou...              0.0
# 2     Ms Geller, of the Atlas Shrugs blog, and Mr Sp...              0.0
# 3     On both of their blogs the pair called their b...              1.0
# 4     The UK should never become a stage for inflamm...              0.0
# ...                                                 ...              ...
# 4142  Comrades, these jokes you have been listening ...              0.0
# ...

# %%
train_cleaned = train_cleaned.groupby('Loaded_Language').head(200)
train_cleaned
# Out:
#                                                   text  Loaded_Language
# 0    Pamela Geller and Robert Spencer co-founded an...              0.0
# 1    He added: "We condemn all those whose behaviou...              0.0
# 2    Ms Geller, of the Atlas Shrugs blog, and Mr Sp...              0.0
# 3    On both of their blogs the pair called their b...              1.0
# 4    The UK should never become a stage for inflamm...              0.0
# ..                                                 ...              ...
# 497  Even if this is true, Muslim migrant violence ...              1.0
# 500  While admitting numerous jihad preachers, Brit...              1.0
# 501  As reported in The Dictator Pope—a remarkable ...              1.0
# 502  Each day, we see new evidence that this might ...              1.0
# 503  Should this happen, the Mystical Body would th...              1.0
#
# [400 rows x 2 columns]

# %%
train_cleaned.to_csv("train_cleaned.csv",index=False)

# %%
test_multi = pd.read_csv("/content/test-multi-label-oana.csv")
test_multi
# Out:
#                                                   text  \
# 0    "The next transmission could be more pronounce...
# 1    This along with poor sanitation and vector con...
# 2    Geneva - The World Health Organisation chief o...
# 3    But Tedros voiced alarm that "plague in Madaga...
# 4    He also pointed to the presence of the pneumon...
# ..                                                 ...
# 982  The U.S. Department of Justice said the court ...
# 983  The Acosta-CNN lawsuit was filed by Ted Boutro...
# 984  The yanking of the physical credential, by the...
# 985  The president described Acosta as "unbelievabl...
# 986  "Journalists need to know that in this country...
#
#                     technique  article_name_x  article_name_y  \
# 0         Appeal_to_Authority       111111111       111111111
# 1         Appeal_to_Authority       111111111       222222222
# 2                       Doubt       111111111       111111111
# ...

# %%
test_multi = test_multi[['text','Loaded_Language', ]]
test_multi
# Out:
#                                                   text  Loaded_Language
# 0    "The next transmission could be more pronounce...                0
# 1    This along with poor sanitation and vector con...                0
# 2    Geneva - The World Health Organisation chief o...                0
# 3    But Tedros voiced alarm that "plague in Madaga...                0
# 4    He also pointed to the presence of the pneumon...                0
# ..                                                 ...              ...
# 982  The U.S. Department of Justice said the court ...                1
# 983  The Acosta-CNN lawsuit was filed by Ted Boutro...                0
# 984  The yanking of the physical credential, by the...                1
# 985  The president described Acosta as "unbelievabl...                0
# 986  "Journalists need to know that in this country...                0
#
# [987 rows x 2 columns]

# %%
nonPropa = pd.read_csv("/content/final-test.csv")
nonPropa = nonPropa[nonPropa['Technique']=='Not propaganda'][['text']]
nonPropa['Loaded_Language']=0
nonPropa
# Out:
#                                                    text  Loaded_Language
# 0     This research group is only interested in viol...                0
# 1         No cop, anywhere, “signed up” to be murdered.                0
# 3     (Both those states are also part of today's fe...                0
# 4     They include probable and suspected cases as w...                0
# 5                  How can a person so unclued survive?                0
# ...                                                 ...              ...
# 3797  “I told the investigator I would be happy to t...                0
# 3798  “We continue to urge the administration to rev...                0
# 3799  Wilders added: “And I tell you, to the governm...                0
# 3800  Clinton told Melvin that at the time the affai...                0
# 3802  The apology was public.” Although some may not...                0
#
# [2917 rows x 2 columns]

# %%
df = pd.concat([test_multi,nonPropa], ignore_index=True)
df = df.sample(frac=1)
df
# Out:
#                                                    text  Loaded_Language
# 3257  The lawsuit says that of the 1,556 provisional...                0
# 2507  Since there are regular flights in and out of ...                0
# 77    “That’s because nearly every threat to peace a...                1
# 3309              * Yes, he should have gotten it back.                0
# 2483  Smith lived there with his wife, Candace, and ...                0
# ...                                                 ...              ...
# 3662                       * Yes, he will be confirmed.                0
# 3346                       America's Immigration Voice.                0
# 2387  The company was set to allow downloads on Wedn...                0
# 656   If Trump is defeated and moved off the table, ...                0
# 3756                 Jean was struck once in the torso.                0
#
# [3904 rows x 2 columns]

# %%
df['Loaded_Language'].value_counts()
# Out:
# 0    3533
# 1     371
# Name: Loaded_Language, dtype: int64

# %%
df.to_csv("loaded_language_test.csv",index=False)

# %%
from datasets import load_dataset


dataset = load_dataset('csv', data_files={'train': "/content/train_cleaned.csv",'test': "/content/loaded_language_test.csv"}, )
dataset
# Out:
# Generating train split: 0 examples [00:00, ? examples/s]
# Generating test split: 0 examples [00:00, ? examples/s]
# DatasetDict({
#     train: Dataset({
#         features: ['text', 'Loaded_Language'],
#         num_rows: 400
#     })
#     test: Dataset({
#         features: ['text', 'Loaded_Language'],
#         num_rows: 3904
#     })
# })

# %%
from setfit import SetFitModel
from sentence_transformers import SentenceTransformer
from sklearn.linear_model import LogisticRegression

# model_body=SentenceTransformer("sentence-transformers/all-roberta-large-v1")
# model_head=LogisticRegression(class_weight="balanced")
# model = SetFitModel(model_body=model_body, model_head=model_head,labels=[0,1],)


# Load a SetFit model from Hub
model = SetFitModel.from_pretrained(
    "sentence-transformers/paraphrase-mpnet-base-v2",
    labels=[0,1],
)

# %%
model.to("cuda")

# %%
from setfit import SetFitModel, Trainer, TrainingArguments, sample_dataset

args = TrainingArguments(
    batch_size=8,
    num_epochs=3,
    evaluation_strategy="epoch",
    save_strategy="epoch",
    load_best_model_at_end=True,
    num_iterations=5,
)

trainer = Trainer(
    model=model,
    args=args,
    train_dataset=dataset['train'],
    eval_dataset=dataset['test'],
    metric="f1",
    column_mapping={"text": "text", "Loaded_Language": "label"}  # Map dataset columns to text/label expected by trainer
)
# Out:
# Applying column mapping to the training dataset
# Applying column mapping to the evaluation dataset
# Map:   0%|          | 0/400 [00:00<?, ? examples/s]

# %%
import torch
training_device = torch.device("cuda") if torch.cuda.is_available() else torch.device("cpu")
training_device
# Out:
# device(type='cuda')

# %%
# Train and evaluate
trainer.train()
# Out:
# ***** Running training *****
#   Num examples = 500
#   Num epochs = 3
#   Total optimization steps = 1500
#   Total train batch size = 8
#     <div>
#
#       <progress value='1500' max='1500' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [1500/1500 1:10:14, Epoch 3/0]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Embedding Loss</th>
#       <th>Rate</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>No log</td>
#       <td>No log</td>
#       <td>0.334200</td>
#       <td>0.000015</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>No log</td>
#       <td>No log</td>
#       <td>0.330300</td>
#       <td>0.000007</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>No log</td>
#       <td>No log</td>
#       <td>0.332700</td>
#       <td>0.000000</td>
# ...

# %%
metrics = trainer.evaluate(dataset['test'])
print(metrics)
# Out:
# Applying column mapping to the evaluation dataset
# ***** Running evaluation *****
# {'f1': 0.3371824480369515}

# %%
trainer.push_to_hub("anismahmahi/Roberta-large-G3-setfit-model")
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# Upload 2 LFS files:   0%|          | 0/2 [00:00<?, ?it/s]
# model.safetensors:   0%|          | 0.00/1.42G [00:00<?, ?B/s]
# model_head.pkl:   0%|          | 0.00/9.02k [00:00<?, ?B/s]
# CommitInfo(commit_url='https://huggingface.co/anismahmahi/Roberta-large-G3-setfit-model/commit/e726dca49a4a37bcc6d60808b42551b8a60cd39c', commit_message='Add SetFit model', commit_description='', oid='e726dca49a4a37bcc6d60808b42551b8a60cd39c', pr_url=None, pr_revision=None, pr_num=None)

# %%
from setfit import SetFitModel
from transformers import AutoTokenizer, AutoModelForSequenceClassification
# Use a pipeline as a high-level helper
from transformers import pipeline

model = SetFitModel.from_pretrained("anismahmahi/improve-G3-setfit-model")
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:88: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/596 [00:00<?, ?B/s]
# .gitattributes:   0%|          | 0.00/1.52k [00:00<?, ?B/s]
# 1_Pooling/config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/14.0k [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/596 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/122 [00:00<?, ?B/s]
# config_setfit.json:   0%|          | 0.00/67.0 [00:00<?, ?B/s]
# ...

# %%
from sklearn.metrics import f1_score,classification_report
preds = model.predict(list(df['text']))

# %%
from sklearn.metrics import f1_score,classification_report
print(classification_report(df['Loaded_Language'],preds))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.96      0.85      0.90      3533
#            1       0.32      0.66      0.43       371
#
#     accuracy                           0.83      3904
#    macro avg       0.64      0.76      0.67      3904
# weighted avg       0.90      0.83      0.86      3904
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
